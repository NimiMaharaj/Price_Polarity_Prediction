# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/Training File.csv')

# %%
df.describe()
# Out:
#            G-DAM MCP        RTM MCP      G-DAM MCV        RTM MCV  \
# count  121152.000000  120405.000000  121152.000000  120405.000000
# mean        5.583201       4.836197     715.855885    3926.790324
# std         2.833031       2.783929     891.564481    1729.646177
# min         0.199950       0.000000      26.700000       0.000000
# 25%         3.700000       3.010000     244.100000    2737.900000
# 50%         4.500000       3.880000     442.500000    3580.100000
# 75%         7.000000       5.570000     863.000000    4732.790000
# max        20.000000      16.740000   10000.000000   17736.000000
#
#        G-DAM Purchase Bid  G-DAM Sell Bid (MW)  RTM Purchase Bid (MW)  \
# count       121152.000000        121152.000000          120405.000000
# mean          2552.577764           976.393190            6798.872160
# std           1360.348952           942.350927            5596.976952
# min            306.600000             0.000000               0.000000
# ...
